# %% [markdown]
# # ARCHISHA SINHA

# %% [markdown]
# a. Apply Sobel’s mask on the given test image to obtain component of gradient |𝑔𝑥|,|𝑔𝑦|𝑎𝑛𝑑
#
# |𝑔𝑥+𝑔𝑦|
#
# b. Apply 5x5 averaging filter on the test image and then implement the sequence in step a.
#
# c. Summarize your observations after comparing the results obtained in step a and b

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
image1=cv.imread('/content/Fig1016(a)(building_original).tif',0)
plt.imshow(image1,cmap='gray')

# %%
[m,n]=image1.shape
print(m,n)
# Out:
# 834 1114

# %% [markdown]
# Horizontal Edge:

# %%
mask=np.array([[-1,-2,-1],[0,0,0],[1,2,1]])

# %%
print(mask)
# Out:
# [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]

# %%
print(image1)
# Out:
# [[230 231 230 ... 230 228 227]
#  [228 228 228 ... 231 231 231]
#  [227 227 225 ... 230 230 228]
#  ...
#  [ 56  62  55 ... 133 115 111]
#  [ 54  50  47 ... 152 129 126]
#  [ 38  27  34 ... 161 142 140]]

# %%
img1=np.zeros([m,n],dtype=int)
for i in range(1,m-1):
  for j in range(1,n-1):
    temp=image1[i-1:i+2,j-1:j+2]
    constant=mask*temp
    constant=np.sum(constant)
    img1[i][j]=constant

plt.imshow(img1,cmap='gray',vmax=255,vmin=0)

# %% [markdown]
# Vertical Edge:

# %%
mask2=np.array([[-1,0,1],[-2,0,2],[-1,0,1]])

# %%
print(mask2)
# Out:
# [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]

# %%
img2=np.zeros([m,n],dtype=int)
for i in range(1,m-1):
  for j in range(1,n-1):
    temp=image1[i-1:i+2,j-1:j+2]
    constant=mask2*temp
    constant=np.sum(constant)
    img2[i][j]=constant

plt.imshow(img2,cmap='gray',vmax=255,vmin=0)

# %% [markdown]
# Diagonal Edge:

# %%
mask3=np.array([[0,1,2],[-1,0,1],[-2,-1,0]])

# %%
print(mask3)
# Out:
# [[ 0  1  2]
#  [-1  0  1]
#  [-2 -1  0]]

# %%
img3=np.zeros([m,n],dtype=int)
for i in range(1,m-1):
  for j in range(1,n-1):
    temp=image1[i-1:i+2,j-1:j+2]
    constant=mask3*temp
    constant=np.sum(constant)
    img3[i][j]=constant

plt.imshow(img3,cmap='gray',vmax=255,vmin=0)

# %% [markdown]
# Diagonal(135):

# %%
mask4=np.array([[1,2,0],[-1,0,1],[0,-2,-1]])

# %%
img4=np.zeros([m,n],dtype=int)
for i in range(1,m-1):
  for j in range(1,n-1):
    temp=image1[i-1:i+2,j-1:j+2]
    constant=mask4*temp
    constant=np.sum(constant)
    img4[i][j]=constant

plt.imshow(img4,cmap='gray',vmax=255,vmin=0)

# %%
Final_image=img1+img2+img3+img4

# %%
plt.imshow(Final_image,cmap='gray',vmax=255,vmin=0)

# %%
# Output dtype = cv2.CV_8U
sob_8u = cv.Sobel(image1,cv.CV_8U,1,0,ksize=3)

# Output dtype = cv2.CV_64F. Then take its absolute and convert to cv2.CV_8U
sobel_64 = cv.Sobel(image1,cv.CV_64F,1,0,ksize=3)
abs_64 = np.absolute(sobel_64)
sobel_8u = np.uint8(abs_64)
cv2_imshow(sobel_8u)
# Out:
# <PIL.Image.Image image mode=L size=1114x834 at 0x7FCDB72AC760>

# %%
plt.imshow(sobel_8u,cmap='gray',vmin=0,vmax=255)
